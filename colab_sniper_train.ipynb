# %% [markdown]
# # 🎯 YOLOv8 Sniper Training: Orange Collector
# Этот блокнот настроен для обучения модели с экстремальной точностью (20,000 эпох).

# %% [markdown]
# ### 1. Подготовка окружения
# Очищаем старые файлы, скачиваем свежий код и ставим библиотеки.

# %%
# !rm -rf /content/drake
# !git clone https://github.com/drakeludo/drake.git /content/drake
# %cd /content/drake
# !pip install ultralytics opencv-python

# %% [markdown]
# ### 2. Проверка GPU
# Убедимся, что видеокарта подключена и видна системе.

# %%
# !nvidia-smi
import torch
print(f"CUDA доступна: {torch.cuda.is_available()}")

# %% [markdown]
# ### 3. Запуск обучения (20,000 эпох)
# **Внимание:** Обучение займет много времени. Результаты будут сохраняться в папку `runs/detect/train`.

# %%
# !python train_hardcore_640.py
