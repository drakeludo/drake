# %% [markdown]
# # 🍊 YOLOv4 Orange Sniper - МЕГА-ОБУЧЕНИЕ (450+ фото)
# Этот ноутбук настроен на максимальную нагрузку:
# - **Датасет**: 450+ изображений с экстремальной аугментацией.
# - **Нагрузка**: Batch Size 64, 8 воркеров.
# - **Авто-сохранение**: Модель сама улетит на GitHub после обучения.
#
# Просто нажмите **Runtime -> Run all**.

# %%
# ШАГ 1: Очистка и клонирование
import os
# %cd /content
if os.path.exists('/content/drake'):
    # !rm -rf /content/drake

token = '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'
# !git clone https://{token}@github.com/drakeludo/drake.git /content/drake

# %%
# ШАГ 2: Обучение
# %cd /content/drake
# !pip install ultralytics opencv-python torch torchvision --quiet
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# !python download_data.py
# !python train_colab.py
